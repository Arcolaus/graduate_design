# %%
import pandas as pd  
import numpy as np
import matplotlib.pyplot as plt  
from scipy import stats

data_file=pd.read_csv("comments.csv",dtype={"id":str,"score":np.float64})

ids=pd.read_csv("movie_detail.csv",dtype={"id":str})["id"]

# print(data_file[data_file["id"]=="11026735"])

for it in ids:
	scores=data_file["score"][data_file["id"]==it]
	print(np.std(scores))
	# print(list(scores))
	# if not np.isnan(np.std(scores,ddof=1)) :
		# print(list(scores))
# Out:
# 0.8385697733787905
# 0.8562499929793108
# 0.8425228353757859
# 0.6606596831048409
# 0.7830808247833608
# 0.7609173363518953
# 0.7811616984630029
# 0.6747285474859103
# 0.7655489346506908
# 1.0177863551523754
# 0.7836994347609327
# 0.7637064877630039
# 0.9804395596862477
# 0.7944981039957625
# 0.7163404647636892
# 0.5834949726109496
# 0.644867929011335
# 0.8390341653067483
# 0.5036343782754711
# 0.989284997994125
# 0.6380480076660363
# 0.8118718798349565
# 0.9201049271670544
# 0.761665992383831
# 0.7332293000538485
# 0.6615888432693634
# 0.6801873229724368
# 1.01001135740414
# 0.7530323961060786
# 0.7179769558216399
# 0.817088028953511
# 0.7125182210688418
# 0.8406549339619881
# 0.9795086398830469
# 0.7459861415020715
# 0.6876820541975388
# 0.7461687725101906
# 0.4982598724270199
# 0.9258206117260862
# 0.8452891892216015
# 0.6711061548476368
# 0.8002048402115444
# 1.0592333242863312
# 0.7093604119806801
# 0.9783795001332518
# 0.7445693191868573
# 1.0158693127582237
# ...
