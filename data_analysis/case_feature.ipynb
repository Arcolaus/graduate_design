# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df=pd.read_csv("../scrapy_data/detail.csv",on_bad_lines='skip')

x=np.array(range(len(df["ratio"])))

y=np.array(df["ratio"])

plt.scatter(x,y,alpha=0.4)
# plt.rcParams['figure.figsize'] = (15, 5)

plt.show()

# %%
import seaborn as sns

d=pd.read_csv("../scrapy_data/contents.csv",on_bad_lines="skip")

plt.hist(np.array(d["score"][d.id==1307315]))

plt.show()
